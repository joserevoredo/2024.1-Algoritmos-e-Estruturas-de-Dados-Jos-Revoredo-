# %% [markdown]
# <a href="https://colab.research.google.com/github/joserevoredo/2024.1-Algoritmos-e-Estruturas-de-Dados-Jos-Revoredo-/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Sistema para calculo de parametros da agua fornecida ')
Nomereg = input("Nome do local de coleta: ")
print('Escreva em ordem os PHS, conforme as intruções abaixo ')
NUMPHS = float(input('Digite o numero de PHS que pretende incerir:'))
print('Caso ja tenha inserido o que deseja apenas digite zero')
n1 = float(input('Digite o primeiro PH encontrado:'))
n2 = float(input('Digite o segundo PH encontrado:'))
n3 = float(input('Digite o terceiro PH encontrado:'))
n4 = float(input('Digite o quarto PH encontrado:'))
n5 = float(input('Digite o quinto PH encontrado:'))
n6 = float(input('Digite o sexto PH encontrado:'))
mediaphgeral01 = (n1 + n2 + n3 + n4 + n5 + n6)/NUMPHS
print('A média do PH do local é:',mediaphgeral01)
if mediaphgeral01 >= 6.5 and mediaphgeral01 <=8.5:
  print("O PH do local está conforme o esperado")
  if mediaphgeral01 > 8.5:
    print("O PH do local está alcalino (Perigo)")
else:
  print("O PH do local está acido (Perigo)")
print('Escreva em ordem as taxas de cor, conforme as intruções abaixo ')
NUMPHS1 = float(input('Digite o numero de itens que pretende incerir:'))
print('Caso ja tenha inserido o que deseja apenas digite zero')
n1 = float(input('Digite a primeira cor encontrada:'))
n2 = float(input('Digite a segunda cor encontrada:'))
n3 = float(input('Digite a terceira cor encontrada:'))
n4 = float(input('Digite a quarta cor encontrada:'))
n5 = float(input('Digite a quinta cor encontrada:'))
n6 = float(input('Digite a sexta cor encontrada:'))
mediaphgeralcor = (n1 + n2 + n3 + n4+n5+n6)/NUMPHS1
print('A média da cor do local é:',mediaphgeralcor)
if mediaphgeralcor < 5:
  print("A cor está conforme a norma")
else:
  if mediaphgeralcor > 5:
    print("A cor está fora de padrão")

coloração_da_região_investigada = mediaphgeralcor
print('Escreva em ordem as taxas de turbidez, conforme as intruções abaixo ')
NUMPHS2 = float(input('Digite o numero de itens que pretende incerir:'))
print('Caso ja tenha inserido o que deseja apenas digite zero')
n1 = float(input('Digite a primeira taxa encontrada:'))
n2 = float(input('Digite a segunda taxa encontrada:'))
n3 = float(input('Digite a terceira taxa encontrada:'))
n4 = float(input('Digite a quarta taxa encontrada:'))
n5 = float(input('Digite a quinta taxa encontrada:'))
n6 = float(input('Digite a sexta taxa encontrada:'))
mediaphgeralturb = (n1 + n2 + n3 + n4 + n5 + n6)/NUMPHS2
print('A taxa de turbidez do local é:',mediaphgeralturb)
if mediaphgeralturb <= 1:
  print("A taxa está conforme a norma")
else:
  if mediaphgeralturb > 1:
    print("A taxa está fora de padrão")

print('Escreva em ordem as taxas de cloro, conforme as intruções abaixo ')
NUMPHS3 = float(input('Digite o numero de itens que pretende incerir:'))
print('Caso ja tenha inserido o que deseja apenas digite zero')
n1 = float(input('Digite a primeira taxa encontrada:'))
n2 = float(input('Digite a segunda taxa encontrada:'))
n3 = float(input('Digite a terceira taxa encontrada:'))
n4 = float(input('Digite a quarta taxa encontrada:'))
n5 = float(input('Digite a quinta taxa encontrada:'))
n6 = float(input('Digite a sexta taxa encontrada:'))
mediaphgeralcloro = (n1 + n2 + n3 + n4 + n5 + n6)/NUMPHS3
print('A taxa de turbidez do local é:',mediaphgeralcloro)
if mediaphgeralcloro > 0.5 and mediaphgeralcloro <=2.5:
  print("A taxa está conforme a norma")
else:
  if mediaphgeralcloro > 2.5:
    print("A taxa está fora de padrão")




c = input("Alguma amostra tem a presença de coliformes:").strip().lower()
if c == 'sim':
  print('Considerada não adequada para contato humano')
else:
  print('considerada adequada para rede de saneamento')

d = input("Foi indentificado a preezença de Fluor:").strip().lower()
if d == 'sim':
  print('considerada adequada para rede de saneamento')
else:
  print('considerada não adequada para rede de saneamento')

print("Resultado final do estudo:")
if mediaphgeral01 >= 6.5 and mediaphgeral01 <=8.5 and mediaphgeralcor < 5 and mediaphgeralturb <= 1 and mediaphgeralcloro > 0.5 and mediaphgeralcloro <2.5 and c == 'sim' and d == 'sim':
  print("AGUA APROVADA PARA CONTATO HUMANO")
else:
  print("AGUA REPROVADA PARA CONTATO HUMANO")
# Out:
# Sistema para calculo de parametros da agua fornecida
# Nome do local de coleta: sul
# Escreva em ordem os PHS, conforme as intruções abaixo
# Digite o numero de PHS que pretende incerir:1
# Caso ja tenha inserido o que deseja apenas digite zero
# Digite o primeiro PH encontrado:7
# Digite o segundo PH encontrado:0
# Digite o terceiro PH encontrado:0
# Digite o quarto PH encontrado:0
# Digite o quinto PH encontrado:0
# Digite o sexto PH encontrado:0
# A média do PH do local é: 7.0
# O PH do local está conforme o esperado
# Escreva em ordem as taxas de cor, conforme as intruções abaixo
# Digite o numero de itens que pretende incerir:1
# Caso ja tenha inserido o que deseja apenas digite zero
# Digite a primeira cor encontrada:3
# Digite a segunda cor encontrada:0
# Digite a terceira cor encontrada:0
# Digite a quarta cor encontrada:0
# Digite a quinta cor encontrada:0
# Digite a sexta cor encontrada:0
# A média da cor do local é: 3.0
# A cor está conforme a norma
# ...

# %%
# Out:
# Escreva em ordem as taxas de turbidez, conforme as intruções abaixo
# Digite o numero de itens que pretende incerir:1
# Caso ja tenha inserido o que deseja apenas digite zero
# Digite a primeira taxa encontrada:0.5
# Digite a segunda taxa encontrada:0
# Digite a terceira taxa encontrada:0
# Digite a quarta taxa encontrada:0
# Digite a quinta taxa encontrada:0
# Digite a sexta taxa encontrada:0
# A taxa de turbidez do local é: 0.5
# A taxa está conforme a norma
# 6
