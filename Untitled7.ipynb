# %% [markdown]
# <a href="https://colab.research.google.com/github/joserevoredo/2024.1-Algoritmos-e-Estruturas-de-Dados-Jos-Revoredo-/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Sistema para calculo de média de parametros da agua fornecida em Natal-RN')
Nomereg = input("ZONA: ")
print('Escreva em ordem os PHS, conforme as intruções abaixo ')
NUMPHS = float(input('Digite o numero de PHS que pretende incerir:'))
print('Caso ja tenha inserido o que deseja apenas digite zero')
n1 = float(input('Digite o primeiro PH encontrado:'))
n2 = float(input('Digite o segundo PH encontrado:'))
n3 = float(input('Digite o terceiro PH encontrado:'))
n4 = float(input('Digite o quarto PH encontrado:'))
n5 = float(input('Digite o quinto PH encontrado:'))
n6 = float(input('Digite o sexto PH encontrado:'))
mediaphgeral01 = (n1 + n2 + n3 + n4 + n5 + n6)/NUMPHS
print('A média do PH do local é:',mediaphgeral01)


Nomereg1 = input("ZONA: ")
print('Escreva em ordem os PHS, conforme as intruções abaixo ')
NUMPHS1 = float(input('Digite o numero de PHS que pretende incerir:'))
print('Caso ja tenha inserido o que deseja apenas digite zero')
n11 = float(input('Digite o primeiro PH encontrado:'))
n22 = float(input('Digite o segundo PH encontrado:'))
n33 = float(input('Digite o terceiro PH encontrado:'))
n44 = float(input('Digite o quarto PH encontrado:'))
n55 = float(input('Digite o quinto PH encontrado:'))
n66 = float(input('Digite o sexto PH encontrado:'))
mediaphgeral02 = (n11 + n22 + n33 + n44 + n55 + n66)/NUMPHS1
print('A média do PH do local é:',mediaphgeral02)

Nomereg2 = input("ZONA: ")
print('Escreva em ordem os PHS, conforme as intruções abaixo ')
NUMPHS2 = float(input('Digite o numero de PHS que pretende incerir:'))
print('Caso ja tenha inserido o que deseja apenas digite zero')
n11 = float(input('Digite o primeiro PH encontrado:'))
n22 = float(input('Digite o segundo PH encontrado:'))
n33 = float(input('Digite o terceiro PH encontrado:'))
n44 = float(input('Digite o quarto PH encontrado:'))
n55 = float(input('Digite o quinto PH encontrado:'))
n66 = float(input('Digite o sexto PH encontrado:'))
mediaphgeral03 = (n11 + n22 + n33 + n44 + n55 + n66)/NUMPHS2
print('A média do PH do local é:',mediaphgeral03)

Nomereg3 = input("ZONA: ")
print('Escreva em ordem os PHS, conforme as intruções abaixo ')
NUMPHS3 = float(input('Digite o numero de PHS que pretende incerir:'))
print('Caso ja tenha inserido o que deseja apenas digite zero')
n11 = float(input('Digite o primeiro PH encontrado:'))
n22 = float(input('Digite o segundo PH encontrado:'))
n33 = float(input('Digite o terceiro PH encontrado:'))
n44 = float(input('Digite o quarto PH encontrado:'))
n55 = float(input('Digite o quinto PH encontrado:'))
n66 = float(input('Digite o sexto PH encontrado:'))
mediaphgeral04 = (n11 + n22 + n33 + n44 + n55 + n66)/NUMPHS3
print('A média do PH do local é:',mediaphgeral04)
# Out:
# Sistema para calculo de média de parametros da agua fornecida em Natal-RN
# ZONA: SUL
# Escreva em ordem os PHS, conforme as intruções abaixo
# Digite o numero de PHS que pretende incerir:2
# Caso ja tenha inserido o que deseja apenas digite zero

# %%
from google.colab import drive
drive.mount('/content/drive')
